# %% [markdown]
# ## Import Libraries

# %%
import sys
sys.path.append("..") # so we can import espresso from the directory above.
import os

import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
import bootstrap_contrast as bsc

import espresso as esp
# Out:
# /Users/josesho/anaconda3/envs/py3.6/lib/python3.6/site-packages/seaborn/apionly.py:6: UserWarning: As seaborn no longer sets a default style on import, the seaborn.apionly module is deprecated. It will be removed in a future version.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Create espresso instances

# %%
git_repo_folder='/Users/josesho/bin/git-repos/espresso'

datadir1=os.path.join(git_repo_folder,'data/by_genotype/Trh-Gal4-Trh-Zal-UAS-GZ-TrpA1/22')
datadir2=os.path.join(git_repo_folder,'data/by_genotype/Trh-Gal4-Trh-Zal-UAS-GZ-TrpA1/29')
datadir3=os.path.join(git_repo_folder,'data/starvation_gradient/0-Hrs')
datadir4=os.path.join(git_repo_folder,'data/starvation_gradient/24-Hrs')

twotubes22=esp.espresso(folder=datadir1)
twotubes29=esp.espresso(folder=datadir2)

starvation0=esp.espresso(folder=datadir3)
starvation24=esp.espresso(folder=datadir4)

# %%
twotubes22
# Out:
# 1 feedlog with a total of 30 flies.
# 3 genotypes detected ['w1118;Trh-Gal4' 'w1118;UAS-Gz-TrpA1;Trh-Zal'
#  'Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL'].
# 1 temperature detected [22].
# 1 foodtype detected ['5% sucrose + 5% yeast extract'].

# %%
twotubes29
# Out:
# 1 feedlog with a total of 30 flies.
# 3 genotypes detected ['w1118;Trh-Gal4' 'w1118;UAS-Gz-TrpA1;Trh-Zal'
#  'Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL'].
# 1 temperature detected [29].
# 1 foodtype detected ['5% sucrose + 5% yeast extract'].

# %%
starvation0
# Out:
# 2 feedlogs with a total of 60 flies.
# 1 genotype detected ['w1118'].
# 1 temperature detected [25].
# 1 foodtype detected ['5% sucrose + 5% yeast extract'].

# %%
starvation24
# Out:
# 2 feedlogs with a total of 60 flies.
# 1 genotype detected ['w1118'].
# 2 temperatures detected [25 22].
# 1 foodtype detected ['5% sucrose + 5% yeast extract'].

# %% [markdown]
# ## Test addition of espresso objects

# %%
trh=twotubes22+twotubes29
trh
# Out:
# 2 feedlogs with a total of 60 flies.
# 3 genotypes detected ['w1118;Trh-Gal4' 'w1118;UAS-Gz-TrpA1;Trh-Zal'
#  'Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL'].
# 2 temperatures detected [22 29].
# 1 foodtype detected ['5% sucrose + 5% yeast extract'].

# %%
starved=starvation0+starvation24
starved
# Out:
# 4 feedlogs with a total of 120 flies.
# 1 genotype detected ['w1118'].
# 2 temperatures detected [25 22].
# 1 foodtype detected ['5% sucrose + 5% yeast extract'].

# %%
sum1=trh+starved # Straight forward summation
sum1
# Out:
# 6 feedlogs with a total of 180 flies.
# 4 genotypes detected ['w1118;Trh-Gal4' 'w1118;UAS-Gz-TrpA1;Trh-Zal'
#  'Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL' 'w1118'].
# 3 temperatures detected [22 29 25].
# 1 foodtype detected ['5% sucrose + 5% yeast extract'].

# %% [markdown]
# ## Test add labels

# %%
for e in [twotubes22, starvation24]:
    e.add_label(label_name='experimenter',label_value='farhan')
    
for e in [twotubes29, starvation0]:
    e.add_label(label_name='experimenter',label_value='quyen')
# Out:
# experimenter has been added as a new label, with 'farhan' as the custom value.
# experimenter has been added as a new label, with 'farhan' as the custom value.
# experimenter has been added as a new label, with 'quyen' as the custom value.
# experimenter has been added as a new label, with 'quyen' as the custom value.

# %%
twotubes22
# Out:
# 1 feedlog with a total of 30 flies.
# 3 genotypes detected ['w1118;Trh-Gal4' 'w1118;UAS-Gz-TrpA1;Trh-Zal'
#  'Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL'].
# 1 temperature detected [22].
# 1 foodtype detected ['5% sucrose + 5% yeast extract'].
# 1 label has been added: ['experimenter']

# %%
for e in [twotubes22, twotubes29, starvation24]:
    e.add_label(label_name='starved_time',label_value='24hr')
starvation0.add_label(label_name='starved_time',label_value='0hr')
# Out:
# starved_time has been added as a new label, with '24hr' as the custom value.
# starved_time has been added as a new label, with '24hr' as the custom value.
# starved_time has been added as a new label, with '24hr' as the custom value.
# starved_time has been added as a new label, with '0hr' as the custom value.

# %%
starvation0
# Out:
# 2 feedlogs with a total of 60 flies.
# 1 genotype detected ['w1118'].
# 1 temperature detected [25].
# 1 foodtype detected ['5% sucrose + 5% yeast extract'].
# 2 labels have been added: ['experimenter', 'starved_time']

# %%
starved=starvation0+starvation24
starved
# Out:
# 4 feedlogs with a total of 120 flies.
# 1 genotype detected ['w1118'].
# 2 temperatures detected [25 22].
# 1 foodtype detected ['5% sucrose + 5% yeast extract'].
# 2 labels have been added: ['experimenter', 'starved_time']

# %%
starved.flies
# Out:
#     Genotype Sex  Minimum Age  Maximum Age                          Tube1  \
# 0      w1118   M            5            7  5% sucrose + 5% yeast extract
# 1      w1118   M            5            7  5% sucrose + 5% yeast extract
# 2      w1118   M            5            7  5% sucrose + 5% yeast extract
# 3      w1118   M            5            7  5% sucrose + 5% yeast extract
# 4      w1118   M            5            7  5% sucrose + 5% yeast extract
# 5      w1118   M            5            7  5% sucrose + 5% yeast extract
# 6      w1118   M            5            7  5% sucrose + 5% yeast extract
# 7      w1118   M            5            7  5% sucrose + 5% yeast extract
# 8      w1118   M            5            7  5% sucrose + 5% yeast extract
# 9      w1118   M            5            7  5% sucrose + 5% yeast extract
# 10     w1118   M            5            7  5% sucrose + 5% yeast extract
# 11     w1118   M            5            7  5% sucrose + 5% yeast extract
# 12     w1118   M            5            7  5% sucrose + 5% yeast extract
# 13     w1118   M            5            7  5% sucrose + 5% yeast extract
# 14     w1118   M            5            7  5% sucrose + 5% yeast extract
# 15     w1118   M            5            7  5% sucrose + 5% yeast extract
# 16     w1118   M            5            7  5% sucrose + 5% yeast extract
# 17     w1118   M            5            7  5% sucrose + 5% yeast extract
# 18     w1118   M            5            7  5% sucrose + 5% yeast extract
# 19     w1118   M            5            7  5% sucrose + 5% yeast extract
# 20     w1118   M            5            7  5% sucrose + 5% yeast extract
# 21     w1118   M            5            7  5% sucrose + 5% yeast extract
# 22     w1118   M            5            7  5% sucrose + 5% yeast extract
# 23     w1118   M            5            7  5% sucrose + 5% yeast extract
# 24     w1118   M            5            7  5% sucrose + 5% yeast extract
# 25     w1118   M            5            7  5% sucrose + 5% yeast extract
# 26     w1118   M            5            7  5% sucrose + 5% yeast extract
# 27     w1118   M            5            7  5% sucrose + 5% yeast extract
# 28     w1118   M            5            7  5% sucrose + 5% yeast extract
# 29     w1118   M            5            7  5% sucrose + 5% yeast extract
# ..       ...  ..          ...          ...                            ...
# 90     w1118   M            5            7  5% sucrose + 5% yeast extract
# 91     w1118   M            5            7  5% sucrose + 5% yeast extract
# 92     w1118   M            5            7  5% sucrose + 5% yeast extract
# 93     w1118   M            5            7  5% sucrose + 5% yeast extract
# 94     w1118   M            5            7  5% sucrose + 5% yeast extract
# 95     w1118   M            5            7  5% sucrose + 5% yeast extract
# 96     w1118   M            5            7  5% sucrose + 5% yeast extract
# 97     w1118   M            5            7  5% sucrose + 5% yeast extract
# 98     w1118   M            5            7  5% sucrose + 5% yeast extract
# 99     w1118   M            5            7  5% sucrose + 5% yeast extract
# 100    w1118   M            5            7  5% sucrose + 5% yeast extract
# 101    w1118   M            5            7  5% sucrose + 5% yeast extract
# 102    w1118   M            5            7  5% sucrose + 5% yeast extract
# 103    w1118   M            5            7  5% sucrose + 5% yeast extract
# 104    w1118   M            5            7  5% sucrose + 5% yeast extract
# 105    w1118   M            5            7  5% sucrose + 5% yeast extract
# 106    w1118   M            5            7  5% sucrose + 5% yeast extract
# 107    w1118   M            5            7  5% sucrose + 5% yeast extract
# 108    w1118   M            5            7  5% sucrose + 5% yeast extract
# 109    w1118   M            5            7  5% sucrose + 5% yeast extract
# 110    w1118   M            5            7  5% sucrose + 5% yeast extract
# 111    w1118   M            5            7  5% sucrose + 5% yeast extract
# 112    w1118   M            5            7  5% sucrose + 5% yeast extract
# 113    w1118   M            5            7  5% sucrose + 5% yeast extract
# 114    w1118   M            5            7  5% sucrose + 5% yeast extract
# 115    w1118   M            5            7  5% sucrose + 5% yeast extract
# 116    w1118   M            5            7  5% sucrose + 5% yeast extract
# 117    w1118   M            5            7  5% sucrose + 5% yeast extract
# 118    w1118   M            5            7  5% sucrose + 5% yeast extract
# 119    w1118   M            5            7  5% sucrose + 5% yeast extract
#
#      Tube2  Temperature  FlyCountInChamber                      FlyID  \
# 0      NaN           25                  1   2017-08-21_10-07-08_Fly1
# 1      NaN           25                  1   2017-08-21_10-07-08_Fly2
# 2      NaN           25                  1   2017-08-21_10-07-08_Fly3
# 3      NaN           25                  1   2017-08-21_10-07-08_Fly4
# 4      NaN           25                  1   2017-08-21_10-07-08_Fly5
# 5      NaN           25                  1   2017-08-21_10-07-08_Fly6
# 6      NaN           25                  1   2017-08-21_10-07-08_Fly7
# 7      NaN           25                  1   2017-08-21_10-07-08_Fly8
# 8      NaN           25                  1   2017-08-21_10-07-08_Fly9
# 9      NaN           25                  1  2017-08-21_10-07-08_Fly10
# 10     NaN           25                  1  2017-08-21_10-07-08_Fly11
# 11     NaN           25                  1  2017-08-21_10-07-08_Fly12
# 12     NaN           25                  1  2017-08-21_10-07-08_Fly13
# 13     NaN           25                  1  2017-08-21_10-07-08_Fly14
# 14     NaN           25                  1  2017-08-21_10-07-08_Fly15
# 15     NaN           25                  1  2017-08-21_10-07-08_Fly16
# 16     NaN           25                  1  2017-08-21_10-07-08_Fly17
# 17     NaN           25                  1  2017-08-21_10-07-08_Fly18
# 18     NaN           25                  1  2017-08-21_10-07-08_Fly19
# 19     NaN           25                  1  2017-08-21_10-07-08_Fly20
# 20     NaN           25                  1  2017-08-21_10-07-08_Fly21
# 21     NaN           25                  1  2017-08-21_10-07-08_Fly22
# 22     NaN           25                  1  2017-08-21_10-07-08_Fly23
# 23     NaN           25                  1  2017-08-21_10-07-08_Fly24
# 24     NaN           25                  1  2017-08-21_10-07-08_Fly25
# 25     NaN           25                  1  2017-08-21_10-07-08_Fly26
# 26     NaN           25                  1  2017-08-21_10-07-08_Fly27
# 27     NaN           25                  1  2017-08-21_10-07-08_Fly28
# 28     NaN           25                  1  2017-08-21_10-07-08_Fly29
# 29     NaN           25                  1  2017-08-21_10-07-08_Fly30
# ..     ...          ...                ...                        ...
# 90     NaN           22                  1   2017-08-11_13-10-31_Fly1
# 91     NaN           22                  1   2017-08-11_13-10-31_Fly2
# 92     NaN           22                  1   2017-08-11_13-10-31_Fly3
# 93     NaN           22                  1   2017-08-11_13-10-31_Fly4
# 94     NaN           22                  1   2017-08-11_13-10-31_Fly5
# 95     NaN           22                  1   2017-08-11_13-10-31_Fly6
# 96     NaN           22                  1   2017-08-11_13-10-31_Fly7
# 97     NaN           22                  1   2017-08-11_13-10-31_Fly8
# 98     NaN           22                  1   2017-08-11_13-10-31_Fly9
# 99     NaN           22                  1  2017-08-11_13-10-31_Fly10
# 100    NaN           22                  1  2017-08-11_13-10-31_Fly11
# 101    NaN           22                  1  2017-08-11_13-10-31_Fly12
# 102    NaN           22                  1  2017-08-11_13-10-31_Fly13
# 103    NaN           22                  1  2017-08-11_13-10-31_Fly14
# 104    NaN           22                  1  2017-08-11_13-10-31_Fly15
# 105    NaN           22                  1  2017-08-11_13-10-31_Fly16
# 106    NaN           22                  1  2017-08-11_13-10-31_Fly17
# 107    NaN           22                  1  2017-08-11_13-10-31_Fly18
# 108    NaN           22                  1  2017-08-11_13-10-31_Fly19
# 109    NaN           22                  1  2017-08-11_13-10-31_Fly20
# 110    NaN           22                  1  2017-08-11_13-10-31_Fly21
# 111    NaN           22                  1  2017-08-11_13-10-31_Fly22
# 112    NaN           22                  1  2017-08-11_13-10-31_Fly23
# 113    NaN           22                  1  2017-08-11_13-10-31_Fly24
# 114    NaN           22                  1  2017-08-11_13-10-31_Fly25
# 115    NaN           22                  1  2017-08-11_13-10-31_Fly26
# 116    NaN           22                  1  2017-08-11_13-10-31_Fly27
# 117    NaN           22                  1  2017-08-11_13-10-31_Fly28
# 118    NaN           22                  1  2017-08-11_13-10-31_Fly29
# 119    NaN           22                  1  2017-08-11_13-10-31_Fly30
#
#     AtLeastOneFeed experimenter starved_time
# 0             True        quyen          0hr
# 1             True        quyen          0hr
# 2            False        quyen          0hr
# 3            False        quyen          0hr
# 4            False        quyen          0hr
# 5             True        quyen          0hr
# 6            False        quyen          0hr
# 7            False        quyen          0hr
# 8            False        quyen          0hr
# 9            False        quyen          0hr
# 10           False        quyen          0hr
# 11           False        quyen          0hr
# 12            True        quyen          0hr
# 13            True        quyen          0hr
# 14           False        quyen          0hr
# 15           False        quyen          0hr
# 16           False        quyen          0hr
# 17           False        quyen          0hr
# 18           False        quyen          0hr
# 19           False        quyen          0hr
# 20           False        quyen          0hr
# 21           False        quyen          0hr
# 22           False        quyen          0hr
# 23           False        quyen          0hr
# 24           False        quyen          0hr
# 25           False        quyen          0hr
# 26           False        quyen          0hr
# 27           False        quyen          0hr
# 28           False        quyen          0hr
# 29           False        quyen          0hr
# ..             ...          ...          ...
# 90            True       farhan         24hr
# 91            True       farhan         24hr
# 92            True       farhan         24hr
# 93            True       farhan         24hr
# 94            True       farhan         24hr
# 95            True       farhan         24hr
# 96            True       farhan         24hr
# 97            True       farhan         24hr
# 98            True       farhan         24hr
# 99            True       farhan         24hr
# 100           True       farhan         24hr
# 101           True       farhan         24hr
# 102           True       farhan         24hr
# 103           True       farhan         24hr
# 104           True       farhan         24hr
# 105          False       farhan         24hr
# 106          False       farhan         24hr
# 107          False       farhan         24hr
# 108           True       farhan         24hr
# 109           True       farhan         24hr
# 110           True       farhan         24hr
# 111           True       farhan         24hr
# 112           True       farhan         24hr
# 113           True       farhan         24hr
# 114           True       farhan         24hr
# 115           True       farhan         24hr
# 116           True       farhan         24hr
# 117           True       farhan         24hr
# 118           True       farhan         24hr
# 119           True       farhan         24hr
#
# [120 rows x 12 columns]

# %%
trh=twotubes22+twotubes29
trh
# Out:
# 2 feedlogs with a total of 60 flies.
# 3 genotypes detected ['w1118;Trh-Gal4' 'w1118;UAS-Gz-TrpA1;Trh-Zal'
#  'Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL'].
# 2 temperatures detected [22 29].
# 1 foodtype detected ['5% sucrose + 5% yeast extract'].
# 2 labels have been added: ['experimenter', 'starved_time']

# %%
trh.flies
# Out:
#                          Genotype Sex  Minimum Age  Maximum Age  \
# 0                  w1118;Trh-Gal4   M            5            7
# 1                  w1118;Trh-Gal4   M            5            7
# 2                  w1118;Trh-Gal4   M            5            7
# 3                  w1118;Trh-Gal4   M            5            7
# 4                  w1118;Trh-Gal4   M            5            7
# 5                  w1118;Trh-Gal4   M            5            7
# 6                  w1118;Trh-Gal4   M            5            7
# 7                  w1118;Trh-Gal4   M            5            7
# 8                  w1118;Trh-Gal4   M            5            7
# 9                  w1118;Trh-Gal4   M            5            7
# 10     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 11     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 12     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 13     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 14     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 15     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 16     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 17     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 18     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 19     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 20  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 21  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 22  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 23  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 24  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 25  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 26  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 27  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 28  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 29  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 30                 w1118;Trh-Gal4   M            5            7
# 31                 w1118;Trh-Gal4   M            5            7
# 32                 w1118;Trh-Gal4   M            5            7
# 33                 w1118;Trh-Gal4   M            5            7
# 34                 w1118;Trh-Gal4   M            5            7
# 35                 w1118;Trh-Gal4   M            5            7
# 36                 w1118;Trh-Gal4   M            5            7
# 37                 w1118;Trh-Gal4   M            5            7
# 38                 w1118;Trh-Gal4   M            5            7
# 39                 w1118;Trh-Gal4   M            5            7
# 40     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 41     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 42     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 43     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 44     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 45     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 46     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 47     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 48     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 49     w1118;UAS-Gz-TrpA1;Trh-Zal   M            5            7
# 50  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 51  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 52  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 53  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 54  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 55  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 56  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 57  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 58  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
# 59  Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL   M            5            7
#
#                             Tube1                          Tube2  Temperature  \
# 0   5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 1   5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 2   5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 3   5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 4   5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 5   5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 6   5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 7   5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 8   5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 9   5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 10  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 11  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 12  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 13  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 14  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 15  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 16  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 17  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 18  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 19  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 20  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 21  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 22  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 23  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 24  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 25  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 26  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 27  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 28  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 29  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           22
# 30  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 31  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 32  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 33  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 34  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 35  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 36  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 37  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 38  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 39  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 40  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 41  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 42  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 43  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 44  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 45  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 46  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 47  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 48  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 49  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 50  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 51  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 52  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 53  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 54  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 55  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 56  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 57  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 58  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
# 59  5% sucrose + 5% yeast extract  5% sucrose + 5% yeast extract           29
#
#     FlyCountInChamber                      FlyID AtLeastOneFeed experimenter  \
# 0                   4   2017-06-16_15-18-47_Fly1           True       farhan
# 1                   4   2017-06-16_15-18-47_Fly2           True       farhan
# 2                   4   2017-06-16_15-18-47_Fly3          False       farhan
# 3                   4   2017-06-16_15-18-47_Fly4           True       farhan
# 4                   4   2017-06-16_15-18-47_Fly5           True       farhan
# 5                   4   2017-06-16_15-18-47_Fly6           True       farhan
# 6                   4   2017-06-16_15-18-47_Fly7           True       farhan
# 7                   4   2017-06-16_15-18-47_Fly8           True       farhan
# 8                   4   2017-06-16_15-18-47_Fly9           True       farhan
# 9                   4  2017-06-16_15-18-47_Fly10           True       farhan
# 10                  4  2017-06-16_15-18-47_Fly11           True       farhan
# 11                  4  2017-06-16_15-18-47_Fly12           True       farhan
# 12                  4  2017-06-16_15-18-47_Fly13           True       farhan
# 13                  4  2017-06-16_15-18-47_Fly14           True       farhan
# 14                  4  2017-06-16_15-18-47_Fly15           True       farhan
# 15                  4  2017-06-16_15-18-47_Fly16           True       farhan
# 16                  4  2017-06-16_15-18-47_Fly17           True       farhan
# 17                  4  2017-06-16_15-18-47_Fly18           True       farhan
# 18                  4  2017-06-16_15-18-47_Fly19           True       farhan
# 19                  4  2017-06-16_15-18-47_Fly20           True       farhan
# 20                  4  2017-06-16_15-18-47_Fly21           True       farhan
# 21                  4  2017-06-16_15-18-47_Fly22           True       farhan
# 22                  4  2017-06-16_15-18-47_Fly23           True       farhan
# 23                  4  2017-06-16_15-18-47_Fly24           True       farhan
# 24                  4  2017-06-16_15-18-47_Fly25           True       farhan
# 25                  4  2017-06-16_15-18-47_Fly26           True       farhan
# 26                  4  2017-06-16_15-18-47_Fly27           True       farhan
# 27                  4  2017-06-16_15-18-47_Fly28          False       farhan
# 28                  4  2017-06-16_15-18-47_Fly29           True       farhan
# 29                  4  2017-06-16_15-18-47_Fly30           True       farhan
# 30                  4   2017-06-08_13-24-26_Fly1           True        quyen
# 31                  4   2017-06-08_13-24-26_Fly2           True        quyen
# 32                  4   2017-06-08_13-24-26_Fly3           True        quyen
# 33                  4   2017-06-08_13-24-26_Fly4           True        quyen
# 34                  4   2017-06-08_13-24-26_Fly5           True        quyen
# 35                  4   2017-06-08_13-24-26_Fly6           True        quyen
# 36                  4   2017-06-08_13-24-26_Fly7           True        quyen
# 37                  4   2017-06-08_13-24-26_Fly8           True        quyen
# 38                  4   2017-06-08_13-24-26_Fly9           True        quyen
# 39                  4  2017-06-08_13-24-26_Fly10           True        quyen
# 40                  4  2017-06-08_13-24-26_Fly11           True        quyen
# 41                  4  2017-06-08_13-24-26_Fly12           True        quyen
# 42                  4  2017-06-08_13-24-26_Fly13           True        quyen
# 43                  4  2017-06-08_13-24-26_Fly14           True        quyen
# 44                  4  2017-06-08_13-24-26_Fly15           True        quyen
# 45                  4  2017-06-08_13-24-26_Fly16           True        quyen
# 46                  4  2017-06-08_13-24-26_Fly17           True        quyen
# 47                  4  2017-06-08_13-24-26_Fly18           True        quyen
# 48                  4  2017-06-08_13-24-26_Fly19           True        quyen
# 49                  4  2017-06-08_13-24-26_Fly20           True        quyen
# 50                  4  2017-06-08_13-24-26_Fly21           True        quyen
# 51                  4  2017-06-08_13-24-26_Fly22           True        quyen
# 52                  4  2017-06-08_13-24-26_Fly23           True        quyen
# 53                  4  2017-06-08_13-24-26_Fly24           True        quyen
# 54                  4  2017-06-08_13-24-26_Fly25           True        quyen
# 55                  4  2017-06-08_13-24-26_Fly26           True        quyen
# 56                  4  2017-06-08_13-24-26_Fly27           True        quyen
# 57                  4  2017-06-08_13-24-26_Fly28           True        quyen
# 58                  4  2017-06-08_13-24-26_Fly29           True        quyen
# 59                  4  2017-06-08_13-24-26_Fly30           True        quyen
#
#    starved_time
# 0          24hr
# 1          24hr
# 2          24hr
# 3          24hr
# 4          24hr
# 5          24hr
# 6          24hr
# 7          24hr
# 8          24hr
# 9          24hr
# 10         24hr
# 11         24hr
# 12         24hr
# 13         24hr
# 14         24hr
# 15         24hr
# 16         24hr
# 17         24hr
# 18         24hr
# 19         24hr
# 20         24hr
# 21         24hr
# 22         24hr
# 23         24hr
# 24         24hr
# 25         24hr
# 26         24hr
# 27         24hr
# 28         24hr
# 29         24hr
# 30         24hr
# 31         24hr
# 32         24hr
# 33         24hr
# 34         24hr
# 35         24hr
# 36         24hr
# 37         24hr
# 38         24hr
# 39         24hr
# 40         24hr
# 41         24hr
# 42         24hr
# 43         24hr
# 44         24hr
# 45         24hr
# 46         24hr
# 47         24hr
# 48         24hr
# 49         24hr
# 50         24hr
# 51         24hr
# 52         24hr
# 53         24hr
# 54         24hr
# 55         24hr
# 56         24hr
# 57         24hr
# 58         24hr
# 59         24hr

# %%
trh.remove_labels('starved_time')
# Out:
# "['starved_time'] has been dropped."

# %%
trh
# Out:
# 2 feedlogs with a total of 60 flies.
# 3 genotypes detected ['w1118;Trh-Gal4' 'w1118;UAS-Gz-TrpA1;Trh-Zal'
#  'Trh-Gal4>UAS-GZ-TrpA1_Trh-ZAL'].
# 2 temperatures detected [22 29].
# 1 foodtype detected ['5% sucrose + 5% yeast extract'].
# 1 label has been added: ['experimenter']

# %%
allexpt=trh+starved
