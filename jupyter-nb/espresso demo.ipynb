# %% [markdown]
# ## Import Libraries

# %%
import sys
sys.path.append("..") # so we can import espresso from the directory above.
import os

import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
import bootstrap_contrast as bsc

import espresso as esp
# Out:
# /Users/josesho/anaconda3/envs/py3.6/lib/python3.6/site-packages/seaborn/apionly.py:6: UserWarning: As seaborn no longer sets a default style on import, the seaborn.apionly module is deprecated. It will be removed in a future version.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Loading Data by Creating espresso instances

# %%
mb312b_folder='/Users/josesho/bin/git-repos/espresso/data/by_genotype/MB312B'
mb312b=esp.espresso(mb312b_folder)

# %%
mb312b
# Out:
# 4 feedlogs with a total of 120 flies.
# 3 genotypes ['w1118;MB312B-Gal4' 'MB312B-Gal4>UAS-TrpA1' 'w1118;UAS-TrpA1'].
# 2 temperatures [22 29].
# 2 foodtypes ['100mM_Sucrose' '100mM_Sucrose_100mM_Arabinose'].

# %% [markdown]
# ## What's Inside?

# %%
mb312b.flies
# Out:
#                   Genotype Sex  Minimum Age  Maximum Age          Tube1  \
# 0        w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 1        w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 2        w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 3        w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 4        w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 5        w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 6        w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 7        w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 8        w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 9        w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 10   MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 11   MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 12   MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 13   MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 14   MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 15   MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 16   MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 17   MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 18   MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 19   MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 20         w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# 21         w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# 22         w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# 23         w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# 24         w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# 25         w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# 26         w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# 27         w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# 28         w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# 29         w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# ..                     ...  ..          ...          ...            ...
# 90       w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 91       w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 92       w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 93       w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 94       w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 95       w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 96       w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 97       w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 98       w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 99       w1118;MB312B-Gal4   M            5            7  100mM_Sucrose
# 100  MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 101  MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 102  MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 103  MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 104  MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 105  MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 106  MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 107  MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 108  MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 109  MB312B-Gal4>UAS-TrpA1   M            5            7  100mM_Sucrose
# 110        w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# 111        w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# 112        w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# 113        w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# 114        w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# 115        w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# 116        w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# 117        w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# 118        w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
# 119        w1118;UAS-TrpA1   M            5            7  100mM_Sucrose
#
#                              Tube2  Temperature  FlyCountInChamber  \
# 0    100mM_Sucrose_100mM_Arabinose           22                  1
# 1    100mM_Sucrose_100mM_Arabinose           22                  1
# 2    100mM_Sucrose_100mM_Arabinose           22                  1
# 3    100mM_Sucrose_100mM_Arabinose           22                  1
# 4    100mM_Sucrose_100mM_Arabinose           22                  1
# 5    100mM_Sucrose_100mM_Arabinose           22                  1
# 6    100mM_Sucrose_100mM_Arabinose           22                  1
# 7    100mM_Sucrose_100mM_Arabinose           22                  1
# 8    100mM_Sucrose_100mM_Arabinose           22                  1
# 9    100mM_Sucrose_100mM_Arabinose           22                  1
# 10   100mM_Sucrose_100mM_Arabinose           22                  1
# 11   100mM_Sucrose_100mM_Arabinose           22                  1
# 12   100mM_Sucrose_100mM_Arabinose           22                  1
# 13   100mM_Sucrose_100mM_Arabinose           22                  1
# 14   100mM_Sucrose_100mM_Arabinose           22                  1
# 15   100mM_Sucrose_100mM_Arabinose           22                  1
# 16   100mM_Sucrose_100mM_Arabinose           22                  1
# 17   100mM_Sucrose_100mM_Arabinose           22                  1
# 18   100mM_Sucrose_100mM_Arabinose           22                  1
# 19   100mM_Sucrose_100mM_Arabinose           22                  1
# 20   100mM_Sucrose_100mM_Arabinose           22                  1
# 21   100mM_Sucrose_100mM_Arabinose           22                  1
2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_Fly9           False
# 99   2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 100  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 101  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 102  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 103  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 104  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 105  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 106  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 107  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 108  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 109  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 110  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 111  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 112  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 113  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 114  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 115  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 116  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 117  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 118  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
# 119  2017-03-31_13-42-10-MB312B-Gal4-UAS-TrpA1-29_F...            True
#
# [120 rows x 10 columns]

# %%
mb312b.feeds.head()
# Out:
#                    StartTime  StartFrame  FeedTubeIdx  \
# 532                      NaN         NaN            0
# 534                      NaN         NaN            1
# 492  14/03/2017 13:36:26.081   4133459.0            0
# 493  14/03/2017 13:40:27.382   4140719.0            0
# 494  14/03/2017 13:40:37.918   4141036.0            0
#
#                                                  FlyID  ChoiceIdx  \
# 532  2017-03-14_13-17-28-MB312B-Gal4-UAS-TrpA1-22_Fly1          0
# 534  2017-03-14_13-17-28-MB312B-Gal4-UAS-TrpA1-22_Fly1          1
# 492  2017-03-14_13-17-28-MB312B-Gal4-UAS-TrpA1-22_Fly1          0
# 493  2017-03-14_13-17-28-MB312B-Gal4-UAS-TrpA1-22_Fly1          0
# 494  2017-03-14_13-17-28-MB312B-Gal4-UAS-TrpA1-22_Fly1          0
#
#                                      AviFile  FeedVol_µl  FeedDuration_ms  \
# 532                                      NIL         NaN              NaN
# 534                                      NIL         NaN              NaN
# 492  FeedEvent_0_2017-03-14_13-36-26.081.avi    0.237945          68506.0
# 493  FeedEvent_0_2017-03-14_13-40-27.382.avi    0.001197           8576.0
# 494  FeedEvent_0_2017-03-14_13-40-37.918.avi    0.001037           3424.0
#
#      Evap-mm3/s  Valid                        ...                          \
# 532         NaN  False                        ...
# 534         NaN  False                        ...
# 492    0.000023   True                        ...
# 493    0.000086   True                        ...
# 494    0.000086   True                        ...
#
#      Maximum Age          Tube1                          Tube2  Temperature  \
# 532            7  100mM_Sucrose  100mM_Sucrose_100mM_Arabinose           22
# 534            7  100mM_Sucrose  100mM_Sucrose_100mM_Arabinose           22
# 492            7  100mM_Sucrose  100mM_Sucrose_100mM_Arabinose           22
# 493            7  100mM_Sucrose  100mM_Sucrose_100mM_Arabinose           22
# 494            7  100mM_Sucrose  100mM_Sucrose_100mM_Arabinose           22
#
#      FlyCountInChamber AverageFeedVolumePerFly_µl AverageFeedCountPerFly  \
# 532                  1                        NaN                    0.0
# 534                  1                        NaN                    0.0
# 492                  1                   0.237945                    1.0
# 493                  1                   0.001197                    1.0
# 494                  1                   0.001037                    1.0
#
#      AverageFeedSpeedPerFly_µl/s                     FoodChoice  \
# 532                          NaN                  100mM_Sucrose
# 534                          NaN  100mM_Sucrose_100mM_Arabinose
# 492                     0.003473                  100mM_Sucrose
# 493                     0.000140                  100mM_Sucrose
# 494                     0.000303                  100mM_Sucrose
#
#                                        FeedLog_rawfile
# 532  FeedLog_2017-03-31_13-42-10-MB312B-Gal4-UAS-Tr...
# 534  FeedLog_2017-03-31_13-42-10-MB312B-Gal4-UAS-Tr...
# 492  FeedLog_2017-03-31_13-42-10-MB312B-Gal4-UAS-Tr...
# 493  FeedLog_2017-03-31_13-42-10-MB312B-Gal4-UAS-Tr...
# 494  FeedLog_2017-03-31_13-42-10-MB312B-Gal4-UAS-Tr...
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Adding Experiments

# %%
mb213b_folder='/Users/josesho/bin/git-repos/espresso/data/by_genotype/MB213B'
mb213b=esp.espresso(mb213b_folder)

# %%
mb213b
# Out:
# 4 feedlogs with a total of 120 flies.
# 3 genotypes ['w1118;MB213B-Gal4' 'MB213B-Gal4>UAS-TrpA1' 'w1118;UAS-TrpA1'].
# 2 temperatures [22 29].
# 2 foodtypes ['100mM_Sucrose' '100mM_Sucrose_100mM_Arabinose'].

# %%
both_mbs=mb312b+mb213b
both_mbs
# Out:
# 8 feedlogs with a total of 240 flies.
# 5 genotypes ['w1118;MB312B-Gal4' 'MB312B-Gal4>UAS-TrpA1' 'w1118;UAS-TrpA1'
#  'w1118;MB213B-Gal4' 'MB213B-Gal4>UAS-TrpA1'].
# 2 temperatures [22 29].
# 2 foodtypes ['100mM_Sucrose' '100mM_Sucrose_100mM_Arabinose'].

# %% [markdown]
# ## Add labels

# %%
# for e in [twotubes22, starvation24]:
#     e.attach_label(label_name='experimenter',label_value='farhan')
    
# for e in [twotubes29, starvation0]:
#     e.attach_label(label_name='experimenter',label_value='quyen')

# %% [markdown]
# ## Creating Plots

# %% [markdown]
# ### Rasters

# %%
mb213b.plot.rasters()
# Out:
# Coloring rasters by FoodChoice
# Grouping rasters by Genotype
# plotting MB213B-Gal4>UAS-TrpA1 rasters
# Be patient, this can a while!
# plotting w1118;MB213B-Gal4 rasters
# Be patient, this can a while!
# plotting w1118;UAS-TrpA1 rasters
# Be patient, this can a while!
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x117d21828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11a975b00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11a9e9e10>], dtype=object)

# %% [markdown]
# ### Percent Feeding

# %%
mb312b.plot.percent_feeding()
# Out:
# (<matplotlib.figure.Figure at 0x11a9952e8>,
#                         percent_feeding    ci_lower    ci_upper
#  Genotype
#  MB312B-Gal4>UAS-TrpA1            100.0  100.000000  100.000000
#  w1118;MB312B-Gal4                 90.0   85.256584   94.743416
#  w1118;UAS-TrpA1                   90.0   85.256584   94.743416)

# %% [markdown]
# ### Time Course Plots

# %%
mb312b.plot.timecourse.feed_count()
# Out:
# Coloring feed volume time course by FoodChoice
# Grouping feed volume time course by Genotype
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11c9da128>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11cb71630>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11cb85d30>], dtype=object)

# %%
mb312b.plot.timecourse.feed_volume()
# Out:
# Coloring feed volume time course by FoodChoice
# Grouping feed volume time course by Genotype
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11dcb2b70>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11cb1a4a8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11cb37b00>], dtype=object)

# %% [markdown]
# ### Cumulative Plots

# %%
mb312b.plot.cumulative.consumption(color_by='FoodChoice',group_by='Temperature')
# Out:
# Coloring feed volume time course by FoodChoice
# Grouping feed volume time course by Temperature
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11e3ec0f0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11e732588>], dtype=object)

# %%
mb312b.plot.cumulative.feed_count()
# Out:
# Coloring feed volume time course by FoodChoice
# Grouping feed volume time course by Genotype
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11e45b6d8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11ca25e48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11d162710>], dtype=object)

# %% [markdown]
# ## Ongoing Development
#
# - Contrast Plots
